# %%
! python setup.py
# Out:
# INFO:root:
# ---- Metadata
# INFO:root:The number of release_date is nan: 90
# INFO:root:The number of genres is nan: 2442
# INFO:root:Check id for nan: 0
# INFO:root:Check imdbId for nan: 17
# INFO:root:Count of unique id: 45416
# INFO:root:Size of dataset: 45446
# INFO:root:Size of dataset without duplicates: 45416
# INFO:root:
# ---- Credits
# INFO:root:Count of unique id: 45432
# INFO:root:Size of dataset: 45476
# INFO:root:Size of dataset without duplicates: 45432
# INFO:root:
# ---- Ratings
# INFO:root:Check how many users have several votes for one movie: True
# INFO:root:Count of unique movieId: 45115
# INFO:root:Size of dataset: 45115
# INFO:root:Size of dataset without duplicates: 45115
# INFO:root:
# ---- Links
# INFO:root:Size of dataset: 45843
# INFO:root:Size of dataset without duplicates: 45843
# INFO:root:Count of unique id: 45416
# INFO:root:Size of dataset: 45416
# INFO:root:Size of dataset without duplicates: 45416
# INFO:root:
# Info for the task
# ...
